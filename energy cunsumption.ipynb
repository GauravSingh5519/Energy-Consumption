# %% [markdown]
# imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as ws
ws.defaultaction = "ignore"

# %% [markdown]
# **Read Data Set**

# %%
csvFile = pd.read_csv("C:\\Users\\Gaurav\\Desktop\\AIF\\python datasets\\long_data_.csv")
print(csvFile)
# Out:
#           States Regions   latitude  longitude                Dates  Usage
# 0         Punjab      NR  31.519974  75.980003  02/01/2019 00:00:00  119.9
# 1        Haryana      NR  28.450006  77.019991  02/01/2019 00:00:00  130.3
# 2      Rajasthan      NR  26.449999  74.639981  02/01/2019 00:00:00  234.1
# 3          Delhi      NR  28.669993  77.230004  02/01/2019 00:00:00   85.8
# 4             UP      NR  27.599981  78.050006  02/01/2019 00:00:00  313.9
# ...          ...     ...        ...        ...                  ...    ...
# 16594    Manipur     NER  24.799971  93.950017  05/12/2020 00:00:00    2.5
# 16595  Meghalaya     NER  25.570492  91.880014  05/12/2020 00:00:00    5.8
# 16596    Mizoram     NER  23.710399  92.720015  05/12/2020 00:00:00    1.6
# 16597   Nagaland     NER  25.666998  94.116570  05/12/2020 00:00:00    2.1
# 16598    Tripura     NER  23.835404  91.279999  05/12/2020 00:00:00    3.3
#
# [16599 rows x 6 columns]

# %% [markdown]
# convert data set into dataframe

# %%
df = pd.read_csv(r'C:\\Users\\Gaurav\\Desktop\\AIF\\python datasets\\long_data_.csv')

# %% [markdown]
# overview of the data frame

# %%
df
# Out:
#           States Regions   latitude  longitude                Dates  Usage
# 0         Punjab      NR  31.519974  75.980003  02/01/2019 00:00:00  119.9
# 1        Haryana      NR  28.450006  77.019991  02/01/2019 00:00:00  130.3
# 2      Rajasthan      NR  26.449999  74.639981  02/01/2019 00:00:00  234.1
# 3          Delhi      NR  28.669993  77.230004  02/01/2019 00:00:00   85.8
# 4             UP      NR  27.599981  78.050006  02/01/2019 00:00:00  313.9
# ...          ...     ...        ...        ...                  ...    ...
# 16594    Manipur     NER  24.799971  93.950017  05/12/2020 00:00:00    2.5
# 16595  Meghalaya     NER  25.570492  91.880014  05/12/2020 00:00:00    5.8
# 16596    Mizoram     NER  23.710399  92.720015  05/12/2020 00:00:00    1.6
# 16597   Nagaland     NER  25.666998  94.116570  05/12/2020 00:00:00    2.1
# 16598    Tripura     NER  23.835404  91.279999  05/12/2020 00:00:00    3.3
#
# [16599 rows x 6 columns]

# %%
df.head(10)
# Out:
#          States Regions   latitude  longitude                Dates  Usage
# 0        Punjab      NR  31.519974  75.980003  02/01/2019 00:00:00  119.9
# 1       Haryana      NR  28.450006  77.019991  02/01/2019 00:00:00  130.3
# 2     Rajasthan      NR  26.449999  74.639981  02/01/2019 00:00:00  234.1
# 3         Delhi      NR  28.669993  77.230004  02/01/2019 00:00:00   85.8
# 4            UP      NR  27.599981  78.050006  02/01/2019 00:00:00  313.9
# 5   Uttarakhand      NR  30.320409  78.050006  02/01/2019 00:00:00   40.7
# 6            HP      NR  31.100025  77.166597  02/01/2019 00:00:00   30.0
# 7           J&K      NR  33.450000  76.240000  02/01/2019 00:00:00   52.5
# 8    Chandigarh      NR  30.719997  76.780006  02/01/2019 00:00:00    5.0
# 9  Chhattisgarh      WR  22.090420  82.159987  02/01/2019 00:00:00   78.7

# %%
df.tail(10)
# Out:
#                   States Regions   latitude  longitude                Dates
# 16589             Odisha      ER  19.820430  85.900017  05/12/2020 00:00:00  \
# 16590        West Bengal      ER  22.580390  88.329947  05/12/2020 00:00:00
# 16591             Sikkim      ER  27.333330  88.616647  05/12/2020 00:00:00
# 16592  Arunachal Pradesh     NER  27.100399  93.616601  05/12/2020 00:00:00
# 16593              Assam     NER  26.749981  94.216667  05/12/2020 00:00:00
# 16594            Manipur     NER  24.799971  93.950017  05/12/2020 00:00:00
# 16595          Meghalaya     NER  25.570492  91.880014  05/12/2020 00:00:00
# 16596            Mizoram     NER  23.710399  92.720015  05/12/2020 00:00:00
# 16597           Nagaland     NER  25.666998  94.116570  05/12/2020 00:00:00
# 16598            Tripura     NER  23.835404  91.279999  05/12/2020 00:00:00
#
#        Usage
# 16589   95.1
# 16590  110.4
# 16591    1.2
# 16592    2.1
# 16593   20.3
# 16594    2.5
# 16595    5.8
# 16596    1.6
# ...

# %%
df.shape
# Out:
# (16599, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16599 entries, 0 to 16598
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   States     16599 non-null  object
#  1   Regions    16599 non-null  object
#  2   latitude   16599 non-null  float64
#  3   longitude  16599 non-null  float64
#  4   Dates      16599 non-null  object
#  5   Usage      16599 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 778.2+ KB

# %%
df.columns
# Out:
# Index(['States', 'Regions', 'latitude', 'longitude', 'Dates', 'Usage'], dtype='object')

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.isnull()
# Out:
#        States  Regions  latitude  longitude  Dates  Usage
# 0       False    False     False      False  False  False
# 1       False    False     False      False  False  False
# 2       False    False     False      False  False  False
# 3       False    False     False      False  False  False
# 4       False    False     False      False  False  False
# ...       ...      ...       ...        ...    ...    ...
# 16594   False    False     False      False  False  False
# 16595   False    False     False      False  False  False
# 16596   False    False     False      False  False  False
# 16597   False    False     False      False  False  False
# 16598   False    False     False      False  False  False
#
# [16599 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# States       0
# Regions      0
# latitude     0
# longitude    0
# Dates        0
# Usage        0
# dtype: int64

# %% [markdown]
# **total usage of electricity**

# %%
df.Usage.sum()
# Out:
# 1709727.9

# %%
df.groupby(["States","Regions"])['Usage'].sum()
# Out:
# States             Regions
# Andhra Pradesh     SR          88604.4
# Arunachal Pradesh  NER          1060.9
# Assam              NER         12554.9
# Bihar              ER          41829.2
# Chandigarh         NR           2083.2
# Chhattisgarh       WR          42190.2
# DNH                WR           8264.6
# Delhi              NR          41940.5
# Goa                WR           5579.9
# Gujarat            WR         162488.9
# HP                 NR          13363.8
# Haryana            NR          69581.8
# J&K                NR          22264.8
# Jharkhand          ER          11992.8
# Karnataka          SR         102665.7
# Kerala             SR          36312.8
# MP                 WR         104766.4
# Maharashtra        WR         217079.8
# Manipur            NER          1254.8
# Meghalaya          NER          2838.8
# Mizoram            NER           858.3
# Nagaland           NER          1087.7
# Odisha             ER          40473.7
# ...

# %% [markdown]
# **NOW DATAFRAME IS LOOKING GOOD SO I AM GOING TO VISUALYSE IT**

# %% [markdown]
# ### **1. PLOTTING**

# %%
import pandas as pd;
csvFile = pd.read_csv("C:\\Users\\Gaurav\\Desktop\\AIF\\python datasets\\long_data_.csv")
print(csvFile)
result = csvFile.groupby(['States', 'Dates'])['Usage'].sum()
print(result)
# Out:
#           States Regions   latitude  longitude                Dates  Usage
# 0         Punjab      NR  31.519974  75.980003  02/01/2019 00:00:00  119.9
# 1        Haryana      NR  28.450006  77.019991  02/01/2019 00:00:00  130.3
# 2      Rajasthan      NR  26.449999  74.639981  02/01/2019 00:00:00  234.1
# 3          Delhi      NR  28.669993  77.230004  02/01/2019 00:00:00   85.8
# 4             UP      NR  27.599981  78.050006  02/01/2019 00:00:00  313.9
# ...          ...     ...        ...        ...                  ...    ...
# 16594    Manipur     NER  24.799971  93.950017  05/12/2020 00:00:00    2.5
# 16595  Meghalaya     NER  25.570492  91.880014  05/12/2020 00:00:00    5.8
# 16596    Mizoram     NER  23.710399  92.720015  05/12/2020 00:00:00    1.6
# 16597   Nagaland     NER  25.666998  94.116570  05/12/2020 00:00:00    2.1
# 16598    Tripura     NER  23.835404  91.279999  05/12/2020 00:00:00    3.3
#
# [16599 rows x 6 columns]
# States          Dates
# ...

# %%
# Creating a new column 'WinningStreak' to track the winning streak for each team
df['Maxusage'] = df['Dates'].ne(df['Usage'].shift()).cumsum()

# %%
# Grouping the data by 'States' and 'max usages' and counting the occurrences
Max_usage = df.groupby(['Dates', 'Maxusage']).size().reset_index(name='Count')

# %%
result = csvFile.groupby(['States', 'Regions'])['Usage'].sum()
print(result)
# Out:
# States             Regions
# Andhra Pradesh     SR          88604.4
# Arunachal Pradesh  NER          1060.9
# Assam              NER         12554.9
# Bihar              ER          41829.2
# Chandigarh         NR           2083.2
# Chhattisgarh       WR          42190.2
# DNH                WR           8264.6
# Delhi              NR          41940.5
# Goa                WR           5579.9
# Gujarat            WR         162488.9
# HP                 NR          13363.8
# Haryana            NR          69581.8
# J&K                NR          22264.8
# Jharkhand          ER          11992.8
# Karnataka          SR         102665.7
# Kerala             SR          36312.8
# MP                 WR         104766.4
# Maharashtra        WR         217079.8
# Manipur            NER          1254.8
# Meghalaya          NER          2838.8
# Mizoram            NER           858.3
# Nagaland           NER          1087.7
# Odisha             ER          40473.7
# ...

# %%
# Plotting 
plt.figure(figsize=(10, 6))
result.plot(kind='line', color='darkblue')
plt.xlabel('')
plt.ylabel('')
plt.title('')
plt.xticks(range(24))
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
csvFile.head(10)
# Out:
#          States Regions   latitude  longitude                Dates  Usage
# 0        Punjab      NR  31.519974  75.980003  02/01/2019 00:00:00  119.9
# 1       Haryana      NR  28.450006  77.019991  02/01/2019 00:00:00  130.3
# 2     Rajasthan      NR  26.449999  74.639981  02/01/2019 00:00:00  234.1
# 3         Delhi      NR  28.669993  77.230004  02/01/2019 00:00:00   85.8
# 4            UP      NR  27.599981  78.050006  02/01/2019 00:00:00  313.9
# 5   Uttarakhand      NR  30.320409  78.050006  02/01/2019 00:00:00   40.7
# 6            HP      NR  31.100025  77.166597  02/01/2019 00:00:00   30.0
# 7           J&K      NR  33.450000  76.240000  02/01/2019 00:00:00   52.5
# 8    Chandigarh      NR  30.719997  76.780006  02/01/2019 00:00:00    5.0
# 9  Chhattisgarh      WR  22.090420  82.159987  02/01/2019 00:00:00   78.7

# %%
csvFile.isnull().sum()
# Out:
# States       0
# Regions      0
# latitude     0
# longitude    0
# Dates        0
# Usage        0
# dtype: int64

# %%
csv_dup=csvFile.duplicated().any()
print(csv_dup)
# Out:
# True

# %%
max_uses_states = csvFile.groupby('Regions')['Usage'].idxmax()
result =csvFile.loc[max_uses_states, ['Regions', 'States', 'Usage']]

# Print the result
print(result)
# Out:
#       Regions       States  Usage
# 13290      ER  West Bengal  198.5
# 5868      NER        Assam   38.0
# 14821      NR           UP  471.8
# 12592      SR   Tamil Nadu  365.4
# 5424       WR  Maharashtra  522.1

# %%
sns.set(style="darkgrid")
sns.countplot(x='Regions',data=csvFile)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'NR'),
#   Text(1, 0, 'WR'),
#   Text(2, 0, 'SR'),
#   Text(3, 0, 'ER'),
#   Text(4, 0, 'NER')])

# %%
plt.barh(width='Usage',y='States',data=csvFile)
plt.xlabel('States')
plt.ylabel('Usage')
plt.title("States by Their Usages")
plt.xticks(rotation=90)
plt.show()

# %%
import plotly.express as px
plt.figure(figsize=(14,6))
sns.barplot(x='Regions',y='Usage',data=csvFile,palette='Blues')
plt.xlabel('Regions')
plt.ylabel("Usage")
plt.title('Cunsumption according to Regions')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14,6))
sns.barplot(x='States',y='Usage',data=csvFile,palette='Blues')
plt.xlabel('States')
plt.ylabel("Usage")
plt.title('Cunsumption according to States')
plt.xticks(rotation=90)
plt.show()

# %%
plt.barh(width='Regions',y='States',data=csvFile)
plt.xlabel('Regions')
plt.ylabel('States')
plt.title("States by Their regions")
plt.xticks(rotation=0)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# **second data set analysis**

# %%
df = pd.read_csv("C:\\Users\\Gaurav\\Desktop\\AIF\\python datasets\\dataset_tk (2).csv", parse_dates = True, index_col = "Unnamed: 0")

# %%
df.head()
# Out:
#                      Punjab  Haryana  Rajasthan  Delhi     UP  Uttarakhand
# 02/01/2019 00:00:00   119.9    130.3      234.1   85.8  313.9         40.7  \
# 03/01/2019 00:00:00   121.9    133.5      240.2   85.5  311.8         39.3
# 04/01/2019 00:00:00   118.8    128.2      239.8   83.5  320.7         38.1
# 05/01/2019 00:00:00   121.0    127.5      239.1   79.2  299.0         39.2
# 06/01/2019 00:00:00   121.4    132.6      240.4   76.6  286.8         39.2
#
#                        HP   J&K  Chandigarh  Chhattisgarh  ...  Odisha
# 02/01/2019 00:00:00  30.0  52.5         5.0          78.7  ...    70.2  \
# 03/01/2019 00:00:00  30.1  54.1         4.9          78.8  ...    67.9
# 04/01/2019 00:00:00  30.1  53.2         4.8          74.8  ...    66.3
# 05/01/2019 00:00:00  30.2  51.5         4.3          69.0  ...    65.8
# 06/01/2019 00:00:00  31.0  53.2         4.3          68.1  ...    62.9
#
#                      West Bengal  Sikkim  Arunachal Pradesh  Assam  Manipur
# ...

# %%
df.columns
# Out:
# Index(['Punjab', 'Haryana', 'Rajasthan', 'Delhi', 'UP', 'Uttarakhand', 'HP',
#        'J&K', 'Chandigarh', 'Chhattisgarh', 'Gujarat', 'MP', 'Maharashtra',
#        'Goa', 'DNH', 'Andhra Pradesh', 'Telangana', 'Karnataka', 'Kerala',
#        'Tamil Nadu', 'Pondy', 'Bihar', 'Jharkhand', 'Odisha', 'West Bengal',
#        'Sikkim', 'Arunachal Pradesh', 'Assam', 'Manipur', 'Meghalaya',
#        'Mizoram', 'Nagaland', 'Tripura'],
#       dtype='object')

# %%
df.index
# Out:
# Index(['02/01/2019 00:00:00', '03/01/2019 00:00:00', '04/01/2019 00:00:00',
#        '05/01/2019 00:00:00', '06/01/2019 00:00:00', '07/01/2019 00:00:00',
#        '08/01/2019 00:00:00', '09/01/2019 00:00:00', '10/01/2019 00:00:00',
#        '11/01/2019 00:00:00',
#        ...
#        '01/11/2020 00:00:00', '02/11/2020 00:00:00', '03/11/2020 00:00:00',
#        '04/11/2020 00:00:00', '05/11/2020 00:00:00', '01/12/2020 00:00:00',
#        '02/12/2020 00:00:00', '03/12/2020 00:00:00', '04/12/2020 00:00:00',
#        '05/12/2020 00:00:00'],
#       dtype='object', length=503)

# %%
plt.figure(figsize=(30,30))
sns.heatmap(df.corr(), annot= True)
plt.show()

# %%
df.shape
# Out:
# (503, 33)

# %%
df.isnull().sum()
# Out:
# Punjab               0
# Haryana              0
# Rajasthan            0
# Delhi                0
# UP                   0
# Uttarakhand          0
# HP                   0
# J&K                  0
# Chandigarh           0
# Chhattisgarh         0
# Gujarat              0
# MP                   0
# Maharashtra          0
# Goa                  0
# DNH                  0
# Andhra Pradesh       0
# Telangana            0
# Karnataka            0
# Kerala               0
# Tamil Nadu           0
# Pondy                0
# Bihar                0
# Jharkhand            0
# Odisha               0
# West Bengal          0
# Sikkim               0
# Arunachal Pradesh    0
# Assam                0
# Manipur              0
# Meghalaya            0
# Mizoram              0
# Nagaland             0
# Tripura              0
# dtype: int64

# %%
mean_temprature = df.mean().sort_values(ascending=False).reset_index().rename(columns = {"index": "state", 0 : "avg_consumption"})
# looks like my state topped the consumption:) 
state_code = ['MH', 'GJ', 'UP', 'TN', 'RJ', 'MP', 'KA', 'TG', 'AP', 'PH', 'WB', 'HR', 'CT', 'DL', 'BR', 'OR', 'KL', 'J&K', 'UK', 'HP', 'AS', 'JH', 'DNH', 'GA', 'PY', 'ML', 'CH', 'TR', 'MN', 'NL', 'AR', 'MZ', 'SK']
mean_temprature.state = state_code

# %%
plt.figure(figsize = (30,30))
sns.barplot(x= "state", y = "avg_consumption", data = mean_temprature)
plt.show()

# %% [markdown]
# ***TIME SERIES ANALYSIS***

# %%
plt.style.use("dark_background")
plt.rcParams.update({'figure.figsize': (40, 10), 'font.size': 24})

# %%
ds = pd.read_csv("C:\\Users\\Gaurav\\Desktop\\AIF\\python datasets\\dataset_tk (2).csv", parse_dates = True, index_col = "Unnamed: 0")

# %%
ds["date"], ds["tn"] = ds[ds.columns[0]], ds["Tamil Nadu"]

# %%
ds.drop(ds.columns[:-2], axis = 1, inplace = True)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 503 entries, 02/01/2019 00:00:00 to 05/12/2020 00:00:00
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    503 non-null    float64
#  1   tn      503 non-null    float64
# dtypes: float64(2)
# memory usage: 11.8+ KB

# %%
ds
# Out:
#                       date     tn
# 02/01/2019 00:00:00  119.9  268.3
# 03/01/2019 00:00:00  121.9  285.2
# 04/01/2019 00:00:00  118.8  270.3
# 05/01/2019 00:00:00  121.0  286.8
# 06/01/2019 00:00:00  121.4  298.3
# ...                    ...    ...
# 01/12/2020 00:00:00  130.8  357.3
# 02/12/2020 00:00:00  129.4  356.9
# 03/12/2020 00:00:00  132.1  355.1
# 04/12/2020 00:00:00  132.1  353.5
# 05/12/2020 00:00:00  120.4  323.7
#
# [503 rows x 2 columns]

# %%
plt.plot(ds["date"], ds["tn"])

# %%
fig = px.line(ds, x='dates', y='Usage')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 fig = px.line(ds, x='dates', y='Usage')
#       2 fig.show()
#
# File c:\Python311\Lib\site-packages\plotly\express\_chart_types.py:264, in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     216 def line(
#     217     data_frame=None,
#     218     x=None,
#    (...)
#     258     height=None,
#     259 ) -> go.Figure:
#     260     """
# ...
